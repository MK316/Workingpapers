# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Workingpapers/blob/main/LDpaper_plotting01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data: https://raw.githubusercontent.com/MK316/Workingpapers/main/results/LD_result_1004.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/MK316/Workingpapers/main/results/LD_result_1004.csv'
data = pd.read_csv(url)

# %%
df1 = data
df1.head()
# Out:
#    Year Category   QN                                            Passage  \
# 0  2015  Context  Q18  One difference between winners and losers is h...
# 1  2015  Context  Q19  As I walked to the train station, I felt the w...
# 2  2015  Context  Q20  Many disciplines are better learned by enterin...
# 3  2015  Context  Q21  The most normal and competent child encounters...
# 4  2015  Context  Q22  The most normal and competent child encounters...
#
#    String                                             Splits  N_Splits  \
# 0     635  ['One', 'difference', 'between', 'winners', 'a...       107
# 1     628  ['As', 'I', 'walked', 'to', 'the', 'train', 's...       123
# 2     715  ['Many', 'disciplines', 'are', 'better', 'lear...       117
# 3     737  ['The', 'most', 'normal', 'and', 'competent', ...       128
# 4     724  ['The', 'most', 'normal', 'and', 'competent', ...       128
#
#                                                Lemma       TTR      RTTR  \
# ...

# %%
df2 = df1[['Year','QN','N_Splits','TTR','MassTTR','MTLD','HDD']]
df2.head()
# Out:
#    Year   QN  N_Splits       TTR   MassTTR        MTLD       HDD
# 0  2015  Q18       107  0.728972  0.033336  110.542069  0.841506
# 1  2015  Q19       123  0.666667  0.040317   62.363391  0.824749
# 2  2015  Q20       117  0.623932  0.047894   53.164604  0.776571
# 3  2015  Q21       128  0.703125  0.034450  112.313726  0.848132
# 4  2015  Q22       128  0.703125  0.034450  112.313726  0.848132

# %% [markdown]
# # Boxplot

# %%
sns.set(rc={'figure.figsize':(15,6),"font.size":40,"axes.titlesize":140,"axes.labelsize":60},style="white") # font size doesn't work
# ax = sns.boxplot (y=df2)
# ax.set_ylim([0, 210])

sns.set_theme(style='white')
dd=pd.melt(df2,id_vars=['Year'],value_vars=['N_Splits'],var_name='Tokens')
ax = sns.boxplot(x='Year',y='value',data=dd,hue='Tokens',palette="Accent")
ax.set_ylim([80,220])
ax.set(xlabel='Year', ylabel='N of words (count)')
plt.savefig('boxplot_Nsplit.png')

# %%
sns.kdeplot(x='HDD', data=df2, hue='Year', common_norm=False);
plt.title("Kernel Density Function");
